# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'20',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3992d073-b41f-4c35-b8fd-4da44d9456dc',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-01T16:15:22.225Z', 'error_code': 0, 'error_message': None, 'elapsed': 19, 'credit_count': 1, 'notice': None, 'total_count': 8838}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10806, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id               name symbol                  slug  num_market_pairs  \
# 0       1            Bitcoin    BTC               bitcoin             10806
# 1    1027           Ethereum    ETH              ethereum              8356
# 2     825        Tether USDt   USDT                tether             73861
# 3    1839                BNB    BNB                   bnb              2048
# 4    5426             Solana    SOL                solana               623
# 5      52                XRP    XRP                   xrp              1223
# 6    3408               USDC   USDC              usd-coin             16509
# 7    2010            Cardano    ADA               cardano              1053
# 8    5805          Avalanche   AVAX             avalanche               656
# 9      74           Dogecoin   DOGE              dogecoin               886
# 10   1958               TRON    TRX                  tron               924
# ...

# %%
def api_executer():
        global df
        url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
        parameters = {
          'start':'1',
          'limit':'20',
          'convert':'USD'
        }
        headers = {
          'Accepts': 'application/json',
          'X-CMC_PRO_API_KEY': '3992d073-b41f-4c35-b8fd-4da44d9456dc',
        }

        session = Session()
        session.headers.update(headers)

        try:
          response = session.get(url, params=parameters)
          data = json.loads(response.text)
          #print(data)
        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)
        
        
        df=pd.json_normalize(data['data'])
        df['Timestamp']=pd.to_datetime('now')
        df
        if not os.path.isfile(r'/Users/icg/AP2.csv'):
            df.to_csv(r'/Users/icg/AP2.csv',header="column_names")
        else:
            df.to_csv(r'/Users/icg/API2.csv',mode='a',header=False)

# %%
import os
from time import time
from time import sleep

# cuz only 333 runs per day in the api 
for i in range(333):
    api_executer()
    print('API runner completed successfully')
    sleep(60) #sleep for 1 minute and run again
exit()
# Out:
# API runner completed successfully
# API runner completed successfully
# API runner completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 9
#       7     api_executer()
#       8     print('API runner completed successfully')
# ----> 9     sleep(60) #sleep for 1 minute and run again
#      10 exit()
#
# KeyboardInterrupt:

# %%
df3=pd.read_csv(r'/Users/icg/API2.csv')
df3
# Out:
#      0      1            Bitcoin    BTC               bitcoin  10806  \
# 0    1   1027           Ethereum    ETH              ethereum   8356
# 1    2    825        Tether USDt   USDT                tether  73861
# 2    3   1839                BNB    BNB                   bnb   2048
# 3    4   5426             Solana    SOL                solana    623
# 4    5     52                XRP    XRP                   xrp   1223
# 5    6   3408               USDC   USDC              usd-coin  16509
# 6    7   2010            Cardano    ADA               cardano   1053
# 7    8   5805          Avalanche   AVAX             avalanche    656
# 8    9     74           Dogecoin   DOGE              dogecoin    886
# 9   10   1958               TRON    TRX                  tron    924
# 10  11   1975          Chainlink   LINK             chainlink   1603
# 11  12   6636           Polkadot    DOT          polkadot-new    681
# 12  13   3890            Polygon  MATIC               polygon   1266
# ...

# %%
df
# Out:
#        id               name symbol                  slug  num_market_pairs  \
# 0       1            Bitcoin    BTC               bitcoin             10806
# 1    1027           Ethereum    ETH              ethereum              8356
# 2     825        Tether USDt   USDT                tether             73861
# 3    1839                BNB    BNB                   bnb              2048
# 4    5426             Solana    SOL                solana               623
# 5      52                XRP    XRP                   xrp              1223
# 6    3408               USDC   USDC              usd-coin             16510
# 7    2010            Cardano    ADA               cardano              1053
# 8    5805          Avalanche   AVAX             avalanche               656
# 9      74           Dogecoin   DOGE              dogecoin               886
# 10   1958               TRON    TRX                  tron               924
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id               name symbol                  slug  num_market_pairs  \
# 0       1            Bitcoin    BTC               bitcoin             10806
# 1    1027           Ethereum    ETH              ethereum              8356
# 2     825        Tether USDt   USDT                tether             73861
# 3    1839                BNB    BNB                   bnb              2048
# 4    5426             Solana    SOL                solana               623
# 5      52                XRP    XRP                   xrp              1223
# 6    3408               USDC   USDC              usd-coin             16510
# 7    2010            Cardano    ADA               cardano              1053
# 8    5805          Avalanche   AVAX             avalanche               656
# 9      74           Dogecoin   DOGE              dogecoin               886
# 10   1958               TRON    TRX                  tron               924
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                    quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                               -0.26678                      -2.09254
# Ethereum                              -0.40136                      -1.83409
# Tether USDt                           -0.02345                      -0.05761
# BNB                                   -0.64538                      -1.91435
# Solana                                -1.13071                      -5.43646
# XRP                                   -0.26518                      -1.91163
# USDC                                  -0.02053                      -0.00505
# Cardano                               -0.89809                      -3.06829
# Avalanche                             -1.34569                      -5.50730
# Dogecoin                              -0.28605                      -0.94422
# TRON                                   0.25732                       2.00659
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin            quote.USD.percent_change_1h     -0.26678
#                    quote.USD.percent_change_24h    -2.09254
#                    quote.USD.percent_change_7d      7.27786
#                    quote.USD.percent_change_30d    -5.54957
#                    quote.USD.percent_change_60d     7.24900
#                    quote.USD.percent_change_90d    22.64499
# Ethereum           quote.USD.percent_change_1h     -0.40136
#                    quote.USD.percent_change_24h    -1.83409
#                    quote.USD.percent_change_7d      4.84676
#                    quote.USD.percent_change_30d    -2.90811
#                    quote.USD.percent_change_60d     6.04847
#                    quote.USD.percent_change_90d    26.28130
# Tether USDt        quote.USD.percent_change_1h     -0.02345
#                    quote.USD.percent_change_24h    -0.05761
#                    quote.USD.percent_change_7d     -0.05463
#                    quote.USD.percent_change_30d    -0.13636
# ...

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                   values
# name
# Bitcoin           quote.USD.percent_change_1h   -0.26678
#                   quote.USD.percent_change_24h  -2.09254
#                   quote.USD.percent_change_7d    7.27786
#                   quote.USD.percent_change_30d  -5.54957
#                   quote.USD.percent_change_60d   7.24900
#                   quote.USD.percent_change_90d  22.64499
# Ethereum          quote.USD.percent_change_1h   -0.40136
#                   quote.USD.percent_change_24h  -1.83409
#                   quote.USD.percent_change_7d    4.84676
#                   quote.USD.percent_change_30d  -2.90811
#                   quote.USD.percent_change_60d   6.04847
#                   quote.USD.percent_change_90d  26.28130
# Tether USDt       quote.USD.percent_change_1h   -0.02345
#                   quote.USD.percent_change_24h  -0.05761
#                   quote.USD.percent_change_7d   -0.05463
# ...

# %%
df5.count()
# Out:
# values    120
# dtype: int64

# %%
index = pd.Index(range(120))
df6 = df5.set_index(index)
df6
# Out:
#        values
# 0    -0.26678
# 1    -2.09254
# 2     7.27786
# 3    -5.54957
# 4     7.24900
# 5    22.64499
# 6    -0.40136
# 7    -1.83409
# 8     4.84676
# 9    -2.90811
# 10    6.04847
# 11   26.28130
# 12   -0.02345
# 13   -0.05761
# 14   -0.05463
# 15   -0.13636
# 16   -0.04954
# 17   -0.12211
# 18   -0.64538
# 19   -1.91435
# 20    2.25069
# 21   -2.91088
# 22   32.06528
# 23   30.43543
# 24   -1.13071
# 25   -5.43646
# 26   11.02425
# 27  -11.84937
# 28   53.23972
# 29  141.07086
# 30   -0.26518
# 31   -1.91163
# 32   -1.26876
# 33  -19.87692
# 34  -19.43356
# 35  -18.13052
# 36   -0.02053
# 37   -0.00505
# 38    0.00366
# 39    0.03673
# 40    0.02843
# 41   -0.00494
# 42   -0.89809
# 43   -3.06829
# 44    5.86181
# 45  -19.62813
# 46   26.40758
# 47   54.09151
# 48   -1.34569
# 49   -5.50730
# 50   11.83818
# 51  -18.63783
# 52   52.93240
# 53  176.20921
# 54   -0.28605
# 55   -0.94422
# 56    2.19943
# 57  -13.40031
# 58   -5.82445
# 59   16.52946
# 60    0.25732
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#        values
# 0    -0.26678
# 1    -2.09254
# 2     7.27786
# 3    -5.54957
# 4     7.24900
# 5    22.64499
# 6    -0.40136
# 7    -1.83409
# 8     4.84676
# 9    -2.90811
# 10    6.04847
# 11   26.28130
# 12   -0.02345
# 13   -0.05761
# 14   -0.05463
# 15   -0.13636
# 16   -0.04954
# 17   -0.12211
# 18   -0.64538
# 19   -1.91435
# 20    2.25069
# 21   -2.91088
# 22   32.06528
# 23   30.43543
# 24   -1.13071
# 25   -5.43646
# 26   11.02425
# 27  -11.84937
# 28   53.23972
# 29  141.07086
# 30   -0.26518
# 31   -1.91163
# 32   -1.26876
# 33  -19.87692
# 34  -19.43356
# 35  -18.13052
# 36   -0.02053
# 37   -0.00505
# 38    0.00366
# 39    0.03673
# 40    0.02843
# 41   -0.00494
# 42   -0.89809
# 43   -3.06829
# 44    5.86181
# 45  -19.62813
# 46   26.40758
# 47   54.09151
# 48   -1.34569
# 49   -5.50730
# 50   11.83818
# 51  -18.63783
# 52   52.93240
# 53  176.20921
# 54   -0.28605
# 55   -0.94422
# 56    2.19943
# 57  -13.40031
# 58   -5.82445
# 59   16.52946
# 60    0.25732
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'percent_change'
#
# The above exception was the direct cause of the following exception:
#
# ...
